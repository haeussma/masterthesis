# %% [markdown]
# # Test book

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyenzyme as pe

# %%
df = pd.read_excel("Daten von 3 Experimenten.xlsx", sheet_name="control_reactions").set_index("Unnamed: 0")
experiment_ids = df.loc["Experiment"].values
df = df.drop(index="Experiment")
df
# Out:
#             0.25 mM  0.25 mM.1  0.5 mM  0.5 mM.1    1 mM  1 mM.1    2 mM  \
# Unnamed: 0
# 0            0.0121     0.0113  0.0219    0.0196  0.0288  0.0231  0.0524
# 1               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 2               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 3               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 4               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 5            0.0402     0.0414  0.0720    0.0669  0.1035  0.1019  0.1750
# 6               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 7               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 8               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 9               NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 10           0.0701     0.0703  0.1216    0.1164  0.1862  0.1866  0.3016
# 11              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 12              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 13              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 14              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 15           0.0964     0.1017  0.1707    0.1654  0.2676  0.2669  0.4223
# 16              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 17              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 18              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 19              NaN        NaN     NaN       NaN     NaN     NaN     NaN
# 20           0.1230     0.1298  0.2189    0.2109  0.3464  0.3463  0.5435
# 30           0.1716     0.1752  0.3099    0.2903  0.4930  0.4979  0.7706
#
#             2 mM.1  0.25 mM.2  0.25 mM.3  0.5 mM.2  0.5 mM.3  1 mM.2  1 mM.3  \
# Unnamed: 0
# 0           0.0452     0.0085     0.0093    0.0170    0.0145  0.0290  0.0309
# 1              NaN     0.0153     0.0156    0.0273    0.0238  0.0467  0.0489
# 2              NaN     0.0218     0.0218    0.0390    0.0334  0.0650  0.0675
# 3              NaN     0.0285     0.0283    0.0496    0.0434  0.0831  0.0862
# 4              NaN     0.0352     0.0349    0.0606    0.0524  0.1009  0.1055
# 5           0.1708     0.0419     0.0409    0.0715    0.0617  0.1169  0.1235
# 6              NaN     0.0487     0.0475    0.0821    0.0712  0.1342  0.1423
# 7              NaN     0.0554     0.0538    0.0931    0.0801  0.1513  0.1598
# 8              NaN     0.0622     0.0602    0.1034    0.0893  0.1699  0.1775
# 9              NaN     0.0686     0.0665    0.1137    0.0984  0.1880  0.1955
# 10          0.3036     0.0752     0.0731    0.1238    0.1079  0.2033  0.2137
# 11             NaN     0.0816     0.0795    0.1334    0.1172  0.2213  0.2304
# 12             NaN     0.0873     0.0857    0.1433    0.1263  0.2362  0.2479
# 13             NaN     0.0935     0.0916    0.1530    0.1352  0.2530  0.2646
# 14             NaN     0.0996     0.0972    0.1631    0.1441  0.2681  0.2807
# 15          0.4285     0.1051     0.1032    0.1731    0.1526  0.2840  0.2965
# 16             NaN     0.1113     0.1090    0.1836    0.1613  0.3002  0.3119
# 17             NaN     0.1172     0.1147    0.1932    0.1694  0.3133  0.3267
# 18             NaN     0.1225     0.1203    0.2027    0.1775  0.3276  0.3421
# 19             NaN     0.1275     0.1252    0.2119    0.1858  0.3413  0.3575
# 20          0.5538     0.1327     0.1308    0.2216    0.1936  0.3566  0.3742
# 30          0.7878     0.1768     0.1750    0.2962    0.2589  0.4820  0.5069
#
#             2 mM.2  2 mM.3  0.5 mM.4  0.5 mM.5
# Unnamed: 0
# 0           0.0425  0.0577    0.0138    0.0145
# 1           0.0663  0.0877       NaN       NaN
# 2           0.0914  0.1176       NaN       NaN
# 3           0.1165  0.1484       NaN       NaN
# 4           0.1400  0.1801       NaN       NaN
# 5           0.1646  0.2130    0.0686    0.0685
# 6           0.1887  0.2429       NaN       NaN
# 7           0.2165  0.2738       NaN       NaN
# 8           0.2415  0.3057       NaN       NaN
# 9           0.2640  0.3336       NaN       NaN
# 10          0.2878  0.3645       NaN       NaN
# 11          0.3118  0.3976       NaN       NaN
# 12          0.3342  0.4253       NaN       NaN
# 13          0.3588  0.4565       NaN       NaN
# 14          0.3800  0.4848       NaN       NaN
# 15          0.4020  0.5161    0.1758    0.1725
# 16          0.4261  0.5433       NaN       NaN
# 17          0.4471  0.5740       NaN       NaN
# 18          0.4653  0.6002       NaN       NaN
# 19          0.4851  0.6269       NaN       NaN
# 20          0.5069  0.6538       NaN       NaN
# 30          0.6723  0.8684    0.3177    0.3121

# %%
data = df.values.T.reshape(9,2,22)
labels = [0.25, 0.5, 1, 2, 0.25, 0.5, 1, 2, 0.5]
colors = ["orange", "blue", "green", "red", "orange", "blue", "green", "red", "blue", ]
markers = ["o", "o", "o", "o", "d", "d", "d", "d", "x", ]

for d, label, color, marker in zip(data, labels, colors, markers):
    mean =np.mean(d, axis=0)
    std =np.std(d, axis=0)
    time = df.index.values

    plt.scatter(time, mean, color=color, label=f"{label} mM", marker=marker)
plt.legend(title="initial substrate")
plt.title("Comparison of chymotrypsin control reactions across three experiment")
plt.ylabel("absorption")
plt.xlabel("time [min]")
plt.show()

# %%
import pyenzymekinetics as pek

# %%
enzmldoc = pe.EnzymeMLDocument.fromTemplate("chymo_HSAwt and HSA(M3).xlsx")
#enzmldoc.visualize()
# Out:
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
product_standard = pek.StandardCurve.from_excel("../round5_control/pNA-standard.xlsx", sheet_name="csv", concentration_unit="mM", substance_name="p-NP")
#product_standard.visualize()
# Out:
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
enzmldoc = pek.abso_to_conc(enzmldoc, product_standard, reactant_id="s1")

# %%
#kin_two_inhibitiors = pek.EnzymeKinetics.from_EnzymeML(enzmldoc, inhibitor_id="s2", inhibitor2_id="s3")
#kin_two_inhibitiors.fit_models(initial_substrates=[0.25, 0.5, 1], start_time=1)
#kin_two_inhibitiors.visualize_fit()

# %%
#enzmldoc.toFile("", name="two_inhibitors")

# %% [markdown]
# ## Seperate analysis

# %%
chymo_HSAwt = pe.EnzymeMLDocument.fromTemplate("/Users/maxhaussler/Dropbox/master_thesis/data/marwa/final/chymo_HSAwt.xlsx")
chymo_HSAM3 = pe.EnzymeMLDocument.fromTemplate("/Users/maxhaussler/Dropbox/master_thesis/data/marwa/final/chymo_HSA(M3).xlsx")

chymo_HSAwt = pek.abso_to_conc(chymo_HSAwt, product_standard, reactant_id="s1")
chymo_HSAM3 = pek.abso_to_conc(chymo_HSAM3, product_standard, reactant_id="s1")
# Out:
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /Users/maxhaussler/miniconda3/envs/pek/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
kin_HSAwt = pek.EnzymeKinetics.from_EnzymeML(chymo_HSAwt, inhibitor_id="s2")
kin_HSAwt.fit_models(initial_substrates=[0.25, 0.5, 1], start_time=1)
kin_HSAwt.visualize_fit("competitive inhibition")
# Out:
# parameter added
# irreversible Michaelis Menten
# irreversible Michaelis Menten with enzyme inactivation
# substrate inhibition
# substrate inhibition with enzyme inactivation
# Substrate dependent enzyme inactivation
# product inhibition
# product inhibition with enzyme inactivation
# competitive inhibition
# competitive inhibition with enzyme inactivation
# uncompetitive inhibition
# uncompetitive inhibition with enzyme inactivation
# non-competitive inhibition
# partially competitive inhibition
#                                                     AIC     kcat [1/min]  \
# competitive inhibition with enzyme inactivation    -780  45.74 +/- 2.35%
# competitive inhibition                             -774  43.03 +/- 0.99%
# uncompetitive inhibition with enzyme inactivation  -742  44.65 +/- 3.65%
# uncompetitive inhibition                           -739  41.96 +/- 1.52%
# non-competitive inhibition                         -737  41.96 +/- 1.42%
# irreversible Michaelis Menten with enzyme inact... -734  43.40 +/- 3.39%
# irreversible Michaelis Menten                      -732  40.80 +/- 1.31%
# product inhibition with enzyme inactivation        -732  43.40 +/- 3.64%
# Substrate dependent enzyme inactivation            -731  39.69 +/- 2.92%
# product inhibition                                 -730  40.96 +/- 5.21%
# substrate inhibition                               -729  40.92 +/- 4.54%
# substrate inhibition with enzyme inactivation      -729   43.74 +/- nan%
# partially competitive inhibition                   -728  40.80 +/- 4.40%
#
#                                                     Km [mmole / l]  \
# competitive inhibition with enzyme inactivation     1.66 +/- 0.12%
# competitive inhibition                              1.66 +/- 0.48%
# uncompetitive inhibition with enzyme inactivation   1.66 +/- 2.49%
# uncompetitive inhibition                            1.66 +/- 0.03%
# non-competitive inhibition                          1.66 +/- 0.44%
# irreversible Michaelis Menten with enzyme inact...  1.66 +/- 0.94%
# irreversible Michaelis Menten                       1.66 +/- 0.01%
# product inhibition with enzyme inactivation         1.66 +/- 0.90%
# Substrate dependent enzyme inactivation             1.66 +/- 1.29%
# product inhibition                                  1.66 +/- 3.03%
# substrate inhibition                                1.66 +/- 4.86%
# substrate inhibition with enzyme inactivation        1.66 +/- nan%
# partially competitive inhibition                    1.66 +/- 4.68%
#
#                                                    ki time-dep enz-inactiv. [1/min]  \
# competitive inhibition with enzyme inactivation                     0.01 +/- 36.36%
# competitive inhibition                                                            -
# uncompetitive inhibition with enzyme inactivation                   0.01 +/- 48.73%
# uncompetitive inhibition                                                          -
# non-competitive inhibition                                                        -
# irreversible Michaelis Menten with enzyme inact...                  0.01 +/- 54.25%
# irreversible Michaelis Menten                                                     -
# product inhibition with enzyme inactivation                         0.01 +/- 54.15%
# Substrate dependent enzyme inactivation                             0.00 +/- 82.11%
# product inhibition                                                                -
# substrate inhibition                                                              -
# substrate inhibition with enzyme inactivation                         0.01 +/- nan%
# partially competitive inhibition                                                  -
#
#                                                    Ki uncompetitive [mmole / l]  \
# competitive inhibition with enzyme inactivation                               -
# competitive inhibition                                                        -
# uncompetitive inhibition with enzyme inactivation               0.14 +/- 31.24%
# uncompetitive inhibition                                        0.14 +/- 35.51%
# non-competitive inhibition                                      0.14 +/- 35.00%
# irreversible Michaelis Menten with enzyme inact...                            -
# irreversible Michaelis Menten                                                 -
# product inhibition with enzyme inactivation                                   -
# Substrate dependent enzyme inactivation                                       -
# product inhibition                                                            -
# substrate inhibition                                          85.65 +/- 589.43%
# substrate inhibition with enzyme inactivation                    34.12 +/- nan%
# partially competitive inhibition                             941.01 +/- 261.96%
#
#                                                    Ki competitive [mmole / l]
# competitive inhibition with enzyme inactivation               0.16 +/- 13.47%
# competitive inhibition                                        0.16 +/- 13.64%
# uncompetitive inhibition with enzyme inactivation                           -
# uncompetitive inhibition                                                    -
# non-competitive inhibition                                520.95 +/- 2043.41%
# irreversible Michaelis Menten with enzyme inact...                          -
# irreversible Michaelis Menten                                               -
# product inhibition with enzyme inactivation               892.37 +/- 6090.77%
# Substrate dependent enzyme inactivation                                     -
# product inhibition                                          7.41 +/- 1017.80%
# substrate inhibition                                                        -
# substrate inhibition with enzyme inactivation                               -
# partially competitive inhibition                          218.97 +/- 1433.74%
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 75
#     # data points      = 60
#     # variables        = 3
#     chi-square         = 1.3532e-04
#     reduced chi-square = 2.3740e-06
#     Akaike info crit   = -774.132480
#     Bayesian info crit = -767.849446
# [[Variables]]
#     k_cat:  43.0308866 +/- 0.42775914 (0.99%) (init = 16.6448)
#     Km:     1.66276833 +/- 0.00797671 (0.48%) (init = 0.00166448)
#     K_ic:   0.16007249 +/- 0.02183799 (13.64%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k_cat, K_ic) = -0.572
#     C(k_cat, Km)   = 0.329
#     C(Km, K_ic)    = 0.159

# %%
kin_HSAM3 = pek.EnzymeKinetics.from_EnzymeML(chymo_HSAM3, inhibitor_id="s3")
kin_HSAM3.fit_models(initial_substrates=[0.25, 0.5, 1], start_time=1)
kin_HSAM3.visualize_fit("competitive inhibition")
# Out:
# parameter added
# irreversible Michaelis Menten
# irreversible Michaelis Menten with enzyme inactivation
# substrate inhibition
# substrate inhibition with enzyme inactivation
# Substrate dependent enzyme inactivation
# product inhibition
# product inhibition with enzyme inactivation
# competitive inhibition
# competitive inhibition with enzyme inactivation
# uncompetitive inhibition
# uncompetitive inhibition with enzyme inactivation
# non-competitive inhibition
# partially competitive inhibition
#                                                     AIC      kcat [1/min]  \
# competitive inhibition with enzyme inactivation    -767   45.31 +/- 2.85%
# competitive inhibition                             -765   42.94 +/- 1.61%
# non-competitive inhibition                         -762   42.94 +/- 2.14%
# uncompetitive inhibition                           -679   41.72 +/- 2.59%
# uncompetitive inhibition with enzyme inactivation  -678   44.11 +/- 6.14%
# irreversible Michaelis Menten                      -627   35.89 +/- 2.72%
# Substrate dependent enzyme inactivation            -626   33.81 +/- 7.12%
# irreversible Michaelis Menten with enzyme inact... -625  37.86 +/- 10.64%
# product inhibition                                 -625  35.82 +/- 19.00%
# substrate inhibition with enzyme inactivation      -623    37.98 +/- nan%
# product inhibition with enzyme inactivation        -623  37.86 +/- 29.05%
# partially competitive inhibition                   -623   35.89 +/- 4.21%
# substrate inhibition                               -616   39.22 +/- 7.42%
#
#                                                      Km [mmole / l]  \
# competitive inhibition with enzyme inactivation      1.66 +/- 0.05%
# competitive inhibition                               1.66 +/- 0.57%
# non-competitive inhibition                           1.66 +/- 2.15%
# uncompetitive inhibition                             1.66 +/- 2.27%
# uncompetitive inhibition with enzyme inactivation    1.66 +/- 0.05%
# irreversible Michaelis Menten                        1.66 +/- 1.52%
# Substrate dependent enzyme inactivation              1.66 +/- 4.87%
# irreversible Michaelis Menten with enzyme inact...  1.66 +/- 20.59%
# product inhibition                                  1.66 +/- 25.90%
# substrate inhibition with enzyme inactivation         1.66 +/- nan%
# product inhibition with enzyme inactivation         1.66 +/- 22.63%
# partially competitive inhibition                     1.66 +/- 4.75%
# substrate inhibition                                 1.66 +/- 0.40%
#
#                                                    ki time-dep enz-inactiv. [1/min]  \
# competitive inhibition with enzyme inactivation                     0.01 +/- 50.55%
# competitive inhibition                                                            -
# non-competitive inhibition                                                        -
# uncompetitive inhibition                                                          -
# uncompetitive inhibition with enzyme inactivation                  0.01 +/- 102.99%
# irreversible Michaelis Menten                                                     -
# Substrate dependent enzyme inactivation                            0.01 +/- 106.74%
# irreversible Michaelis Menten with enzyme inact...                 0.01 +/- 174.17%
# product inhibition                                                                -
# substrate inhibition with enzyme inactivation                         0.01 +/- nan%
# product inhibition with enzyme inactivation                        0.01 +/- 242.50%
# partially competitive inhibition                                                  -
# substrate inhibition                                                              -
#
#                                                    Ki uncompetitive [mmole / l]  \
# competitive inhibition with enzyme inactivation                               -
# competitive inhibition                                                        -
# non-competitive inhibition                                     1.32 +/- 998.64%
# uncompetitive inhibition                                        0.02 +/- 12.90%
# uncompetitive inhibition with enzyme inactivation               0.02 +/- 13.83%
# irreversible Michaelis Menten                                                 -
# Substrate dependent enzyme inactivation                                       -
# irreversible Michaelis Menten with enzyme inact...                            -
# product inhibition                                                            -
# substrate inhibition with enzyme inactivation                    83.11 +/- nan%
# product inhibition with enzyme inactivation                                   -
# partially competitive inhibition                            792.68 +/- 7000.36%
# substrate inhibition                                            2.75 +/- 76.59%
#
#                                                    Ki competitive [mmole / l]
# competitive inhibition with enzyme inactivation                0.04 +/- 5.42%
# competitive inhibition                                         0.04 +/- 6.03%
# non-competitive inhibition                                    0.04 +/- 14.60%
# uncompetitive inhibition                                                    -
# uncompetitive inhibition with enzyme inactivation                           -
# irreversible Michaelis Menten                                               -
# Substrate dependent enzyme inactivation                                     -
# irreversible Michaelis Menten with enzyme inact...                          -
# product inhibition                                         931.23 +/- 100.83%
# substrate inhibition with enzyme inactivation                               -
# product inhibition with enzyme inactivation             606.99 +/- 331972.98%
# partially competitive inhibition                            999.84 +/- 81.22%
# substrate inhibition                                                        -
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 102
#     # data points      = 60
#     # variables        = 3
#     chi-square         = 1.5684e-04
#     reduced chi-square = 2.7516e-06
#     Akaike info crit   = -765.276639
#     Bayesian info crit = -758.993606
# [[Variables]]
#     k_cat:  42.9419697 +/- 0.69286722 (1.61%) (init = 16.6448)
#     Km:     1.66447591 +/- 0.00953710 (0.57%) (init = 0.00166448)
#     K_ic:   0.03847993 +/- 0.00231989 (6.03%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k_cat, Km)   = 0.777
#     C(k_cat, K_ic) = -0.637
#     C(Km, K_ic)    = -0.398

# %%
kin_HSAM3.visualize_fit()
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 67
#     # data points      = 60
#     # variables        = 4
#     chi-square         = 1.4640e-04
#     reduced chi-square = 2.6142e-06
#     Akaike info crit   = -767.412000
#     Bayesian info crit = -759.034622
# [[Variables]]
#     k_cat:  45.3082357 +/- 1.29153360 (2.85%) (init = 16.6448)
#     Km:     1.66448000 +/- 7.5657e-04 (0.05%) (init = 0.00166448)
#     K_ie:   0.00530893 +/- 0.00268371 (50.55%) (init = 0.01)
#     K_ic:   0.03848833 +/- 0.00208631 (5.42%) (init = 0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k_cat, K_ie) = 0.936
#     C(k_cat, K_ic) = -0.201
#     C(Km, K_ic)    = -0.104
